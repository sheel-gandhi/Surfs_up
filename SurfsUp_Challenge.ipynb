# %%
# Dependencies
import numpy as np
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
june_filter = session.query(Measurement.date, Measurement.tobs).filter(extract('month',Measurement.date) == "06").all()

# %%
#  3. Convert the June temperatures to a list.
june_temp = []
june_temp = june_filter
print(june_temp)
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
# Save the query results as a Pandas DataFrame and set the index to the date column
# df = pd.DataFrame(results, columns=['date','precipitation'])
# df.set_index(df['date'], inplace=True)
# print(df)
# print(df.to_string(index=False))

june_temp_df = pd.DataFrame(june_temp, columns=['date','temperature'])
june_temp_df.set_index(june_temp_df["date"], inplace=True)
print(june_temp_df.to_string(index=False))
# Out:
#       date  temperature
# 2010-06-01         78.0
# 2010-06-02         76.0
# 2010-06-03         78.0
# 2010-06-04         76.0
# 2010-06-05         77.0
# 2010-06-06         78.0
# 2010-06-07         77.0
# 2010-06-08         78.0
# 2010-06-09         78.0
# 2010-06-10         79.0
# 2010-06-11         78.0
# 2010-06-12         78.0
# 2010-06-13         78.0
# 2010-06-14         77.0
# 2010-06-15         78.0
# 2010-06-16         78.0
# 2010-06-17         77.0
# 2010-06-18         77.0
# 2010-06-19         82.0
# 2010-06-20         78.0
# 2010-06-21         78.0
# 2010-06-22         78.0
# 2010-06-23         78.0
# 2010-06-24         78.0
# 2010-06-25         77.0
# 2010-06-26         76.0
# 2010-06-27         78.0
# 2010-06-28         78.0
# 2010-06-29         78.0
# 2010-06-30         78.0
# 2011-06-01         77.0
# 2011-06-02         78.0
# 2011-06-03         73.0
# 2011-06-04         70.0
# 2011-06-05         76.0
# 2011-06-06         77.0
# 2011-06-07         77.0
# ...

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_temp_df.describe()
# Out:
#        temperature
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_filter = session.query(Measurement.date, Measurement.tobs).filter(extract('month',Measurement.date) == "12").all()

# %%
# 7. Convert the December temperatures to a list.
dec_temp = []
dec_temp = dec_filter
print(dec_temp)
# Out:
# [('2010-12-01', 76.0), ('2010-12-03', 74.0), ('2010-12-04', 74.0), ('2010-12-06', 64.0), ('2010-12-07', 64.0), ('2010-12-08', 67.0), ('2010-12-09', 77.0), ('2010-12-10', 66.0), ('2010-12-11', 69.0), ('2010-12-12', 68.0), ('2010-12-13', 68.0), ('2010-12-14', 71.0), ('2010-12-15', 74.0), ('2010-12-16', 67.0), ('2010-12-17', 66.0), ('2010-12-18', 69.0), ('2010-12-19', 71.0), ('2010-12-23', 70.0), ('2010-12-24', 70.0), ('2010-12-26', 74.0), ('2010-12-27', 74.0), ('2010-12-28', 71.0), ('2010-12-29', 75.0), ('2010-12-30', 75.0), ('2010-12-31', 72.0), ('2011-12-01', 69.0), ('2011-12-02', 68.0), ('2011-12-03', 73.0), ('2011-12-04', 74.0), ('2011-12-05', 73.0), ('2011-12-06', 73.0), ('2011-12-07', 73.0), ('2011-12-08', 73.0), ('2011-12-09', 71.0), ('2011-12-10', 73.0), ('2011-12-11', 73.0), ('2011-12-12', 77.0), ('2011-12-13', 72.0), ('2011-12-14', 71.0), ('2011-12-15', 73.0), ('2011-12-16', 70.0), ('2011-12-17', 73.0), ('2011-12-18', 69.0), ('2011-12-19', 74.0), ('2011-12-20', 72.0), ('2011-
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_temp_df = pd.DataFrame(dec_temp, columns=['date','temperature'])
dec_temp_df.set_index(dec_temp_df["date"], inplace=True)
print(dec_temp_df.to_string(index=False))
# Out:
#       date  temperature
# 2010-12-01         76.0
# 2010-12-03         74.0
# 2010-12-04         74.0
# 2010-12-06         64.0
# 2010-12-07         64.0
# 2010-12-08         67.0
# 2010-12-09         77.0
# 2010-12-10         66.0
# 2010-12-11         69.0
# 2010-12-12         68.0
# 2010-12-13         68.0
# 2010-12-14         71.0
# 2010-12-15         74.0
# 2010-12-16         67.0
# 2010-12-17         66.0
# 2010-12-18         69.0
# 2010-12-19         71.0
# 2010-12-23         70.0
# 2010-12-24         70.0
# 2010-12-26         74.0
# 2010-12-27         74.0
# 2010-12-28         71.0
# 2010-12-29         75.0
# 2010-12-30         75.0
# 2010-12-31         72.0
# 2011-12-01         69.0
# 2011-12-02         68.0
# 2011-12-03         73.0
# 2011-12-04         74.0
# 2011-12-05         73.0
# 2011-12-06         73.0
# 2011-12-07         73.0
# 2011-12-08         73.0
# 2011-12-09         71.0
# 2011-12-10         73.0
# 2011-12-11         73.0
# 2011-12-12         77.0
# ...

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_temp_df.describe()
# Out:
#        temperature
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %% [markdown]
# ### Additional Results and Queries

# %%
# query that filters the Measurement table to retrieve the precipitation for the month of June. 
june_filter_prcp = session.query(Measurement.date, Measurement.prcp).filter(extract('month',Measurement.date) == "06").all()

# %%
june_prcp = []
june_prcp = june_filter_prcp
print(june_prcp)
# Out:
# [('2010-06-01', 0.0), ('2010-06-02', 0.01), ('2010-06-03', 0.0), ('2010-06-04', 0.0), ('2010-06-05', 0.0), ('2010-06-06', 0.0), ('2010-06-07', 0.0), ('2010-06-08', 0.0), ('2010-06-09', 0.0), ('2010-06-10', 0.0), ('2010-06-11', 0.0), ('2010-06-12', 0.0), ('2010-06-13', 0.0), ('2010-06-14', 0.0), ('2010-06-15', 0.0), ('2010-06-16', 0.0), ('2010-06-17', 0.0), ('2010-06-18', 0.0), ('2010-06-19', 0.0), ('2010-06-20', 0.0), ('2010-06-21', 0.0), ('2010-06-22', 0.0), ('2010-06-23', 0.0), ('2010-06-24', 0.0), ('2010-06-25', 0.0), ('2010-06-26', 0.02), ('2010-06-27', 0.0), ('2010-06-28', 0.0), ('2010-06-29', 0.0), ('2010-06-30', 0.0), ('2011-06-01', 0.07), ('2011-06-02', 0.0), ('2011-06-03', 0.56), ('2011-06-04', 0.89), ('2011-06-05', 0.0), ('2011-06-06', 0.0), ('2011-06-07', 0.0), ('2011-06-08', 0.03), ('2011-06-09', 0.01), ('2011-06-10', 0.0), ('2011-06-11', 0.0), ('2011-06-12', 0.0), ('2011-06-13', 0.0), ('2011-06-14', 0.0), ('2011-06-15', 0.0), ('2011-06-17', 0.0), ('2011-06-18', 0.0), ('2
# ...

# %%
june_prcp_df = pd.DataFrame(june_prcp, columns=['date','precipitation'])
june_prcp_df.set_index(june_prcp_df["date"], inplace=True)
print(june_prcp_df.to_string(index=False))
# Out:
#       date  precipitation
# 2010-06-01           0.00
# 2010-06-02           0.01
# 2010-06-03           0.00
# 2010-06-04           0.00
# 2010-06-05           0.00
# 2010-06-06           0.00
# 2010-06-07           0.00
# 2010-06-08           0.00
# 2010-06-09           0.00
# 2010-06-10           0.00
# 2010-06-11           0.00
# 2010-06-12           0.00
# 2010-06-13           0.00
# 2010-06-14           0.00
# 2010-06-15           0.00
# 2010-06-16           0.00
# 2010-06-17           0.00
# 2010-06-18           0.00
# 2010-06-19           0.00
# 2010-06-20           0.00
# 2010-06-21           0.00
# 2010-06-22           0.00
# 2010-06-23           0.00
# 2010-06-24           0.00
# 2010-06-25           0.00
# 2010-06-26           0.02
# 2010-06-27           0.00
# 2010-06-28           0.00
# 2010-06-29           0.00
# 2010-06-30           0.00
# 2011-06-01           0.07
# 2011-06-02           0.00
# 2011-06-03           0.56
# 2011-06-04           0.89
# ...

# %%
june_prcp_df.describe()
# Out:
#        precipitation
# count    1574.000000
# mean        0.136360
# std         0.335731
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.120000
# max         4.430000

# %%
# query that filters the Measurement table to retrieve the precipitation for the month of December. 
dec_filter_prcp = session.query(Measurement.date, Measurement.prcp).filter(extract('month',Measurement.date) == "12").all()

# %%
dec_prcp = []
dec_prcp = dec_filter_prcp
print(dec_prcp)
# Out:
# [('2010-12-01', 0.04), ('2010-12-03', 0.0), ('2010-12-04', 0.0), ('2010-12-06', 0.0), ('2010-12-07', 0.0), ('2010-12-08', 0.0), ('2010-12-09', 0.0), ('2010-12-10', 1.58), ('2010-12-11', 0.77), ('2010-12-12', 0.0), ('2010-12-13', 0.0), ('2010-12-14', 0.0), ('2010-12-15', 0.0), ('2010-12-16', 0.0), ('2010-12-17', 0.0), ('2010-12-18', 0.0), ('2010-12-19', 1.4), ('2010-12-23', 0.0), ('2010-12-24', 0.0), ('2010-12-26', None), ('2010-12-27', 0.13), ('2010-12-28', 0.55), ('2010-12-29', 0.06), ('2010-12-30', 0.01), ('2010-12-31', 0.0), ('2011-12-01', 0.03), ('2011-12-02', 0.08), ('2011-12-03', 0.0), ('2011-12-04', 0.0), ('2011-12-05', 0.0), ('2011-12-06', 0.0), ('2011-12-07', 0.0), ('2011-12-08', 0.0), ('2011-12-09', 0.13), ('2011-12-10', 0.07), ('2011-12-11', 0.07), ('2011-12-12', 0.08), ('2011-12-13', 0.4), ('2011-12-14', 0.7), ('2011-12-15', 0.0), ('2011-12-16', 0.01), ('2011-12-17', 0.07), ('2011-12-18', 0.02), ('2011-12-19', 0.15), ('2011-12-20', 0.02), ('2011-12-21', 0.18), ('2011-12-2
# ...

# %%
dec_prcp_df = pd.DataFrame(dec_prcp, columns=['date','precipitation'])
dec_prcp_df.set_index(dec_prcp_df["date"], inplace=True)
print(dec_prcp_df.to_string(index=False))
# Out:
#       date  precipitation
# 2010-12-01           0.04
# 2010-12-03           0.00
# 2010-12-04           0.00
# 2010-12-06           0.00
# 2010-12-07           0.00
# 2010-12-08           0.00
# 2010-12-09           0.00
# 2010-12-10           1.58
# 2010-12-11           0.77
# 2010-12-12           0.00
# 2010-12-13           0.00
# 2010-12-14           0.00
# 2010-12-15           0.00
# 2010-12-16           0.00
# 2010-12-17           0.00
# 2010-12-18           0.00
# 2010-12-19           1.40
# 2010-12-23           0.00
# 2010-12-24           0.00
# 2010-12-26            NaN
# 2010-12-27           0.13
# 2010-12-28           0.55
# 2010-12-29           0.06
# 2010-12-30           0.01
# 2010-12-31           0.00
# 2011-12-01           0.03
# 2011-12-02           0.08
# 2011-12-03           0.00
# 2011-12-04           0.00
# 2011-12-05           0.00
# 2011-12-06           0.00
# 2011-12-07           0.00
# 2011-12-08           0.00
# 2011-12-09           0.13
# ...

# %%
dec_prcp_df.describe()
# Out:
#        precipitation
# count    1405.000000
# mean        0.216819
# std         0.541399
# min         0.000000
# 25%         0.000000
# 50%         0.030000
# 75%         0.150000
# max         6.420000

# %%
june_temp_df.plot.hist(bins = 12)
plt.title('June Temperatures')
plt.xlim([55, 85])
plt.ylim([0,400])
plt.tight_layout()

# %%
dec_temp_df.plot.hist(bins = 12)
plt.title('December Temperatures')
plt.xlim([55, 85])
plt.ylim([0,400])
plt.tight_layout()

# %%
june_prcp_df.plot.hist(bins = 15)
plt.title('June Precipitation')
plt.xlim([0,6.5])
plt.ylim([0,1400])
plt.tight_layout()

# %%
dec_prcp_df.plot.hist(bins = 15)
plt.title('December Precipitation')
plt.xlim([0,6.5])
plt.ylim([0,1400])
plt.tight_layout()

# %%
# query that filters the Measurement table to retrieve the precipitation & temperature for the month of June. 
june_temp_prcp = session.query(Measurement.date, Measurement.tobs, Measurement.prcp).filter(extract('month',Measurement.date) == "06").all()
june_temp_prcp
# Out:
# [('2010-06-01', 78.0, 0.0),
#  ('2010-06-02', 76.0, 0.01),
#  ('2010-06-03', 78.0, 0.0),
#  ('2010-06-04', 76.0, 0.0),
#  ('2010-06-05', 77.0, 0.0),
#  ('2010-06-06', 78.0, 0.0),
#  ('2010-06-07', 77.0, 0.0),
#  ('2010-06-08', 78.0, 0.0),
#  ('2010-06-09', 78.0, 0.0),
#  ('2010-06-10', 79.0, 0.0),
#  ('2010-06-11', 78.0, 0.0),
#  ('2010-06-12', 78.0, 0.0),
#  ('2010-06-13', 78.0, 0.0),
#  ('2010-06-14', 77.0, 0.0),
#  ('2010-06-15', 78.0, 0.0),
#  ('2010-06-16', 78.0, 0.0),
#  ('2010-06-17', 77.0, 0.0),
#  ('2010-06-18', 77.0, 0.0),
#  ('2010-06-19', 82.0, 0.0),
#  ('2010-06-20', 78.0, 0.0),
#  ('2010-06-21', 78.0, 0.0),
#  ('2010-06-22', 78.0, 0.0),
#  ('2010-06-23', 78.0, 0.0),
#  ('2010-06-24', 78.0, 0.0),
#  ('2010-06-25', 77.0, 0.0),
#  ('2010-06-26', 76.0, 0.02),
#  ('2010-06-27', 78.0, 0.0),
#  ('2010-06-28', 78.0, 0.0),
#  ('2010-06-29', 78.0, 0.0),
#  ('2010-06-30', 78.0, 0.0),
#  ('2011-06-01', 77.0, 0.07),
#  ('2011-06-02', 78.0, 0.0),
#  ('2011-06-03', 73.0, 0.56),
# ...

# %%
june_temp_prcp_df = pd.DataFrame(june_temp_prcp, columns=['date','temperature', 'precipitation'])
june_temp_prcp_df.set_index(june_temp_prcp_df["date"], inplace=True)
print(june_temp_prcp_df.to_string(index=False))
# Out:
#       date  temperature  precipitation
# 2010-06-01         78.0           0.00
# 2010-06-02         76.0           0.01
# 2010-06-03         78.0           0.00
# 2010-06-04         76.0           0.00
# 2010-06-05         77.0           0.00
# 2010-06-06         78.0           0.00
# 2010-06-07         77.0           0.00
# 2010-06-08         78.0           0.00
# 2010-06-09         78.0           0.00
# 2010-06-10         79.0           0.00
# 2010-06-11         78.0           0.00
# 2010-06-12         78.0           0.00
# 2010-06-13         78.0           0.00
# 2010-06-14         77.0           0.00
# 2010-06-15         78.0           0.00
# 2010-06-16         78.0           0.00
# 2010-06-17         77.0           0.00
# 2010-06-18         77.0           0.00
# 2010-06-19         82.0           0.00
# 2010-06-20         78.0           0.00
# 2010-06-21         78.0           0.00
# 2010-06-22         78.0           0.00
# 2010-06-23         78.0           0.00
# ...

# %%
june_temp_prcp_clean_df = june_temp_prcp_df.dropna()

# %%
june_temp_prcp_clean_df.describe()
# Out:
#        temperature  precipitation
# count  1574.000000    1574.000000
# mean     74.887548       0.136360
# std       3.255695       0.335731
# min      65.000000       0.000000
# 25%      72.000000       0.000000
# 50%      75.000000       0.020000
# 75%      77.000000       0.120000
# max      85.000000       4.430000

# %%
june_temp_prcp_clean_df.plot.scatter('temperature', 'precipitation')
plt.title('June Temperature by Precipitation')
plt.xlim([55, 85])
plt.ylim([0,8])
plt.tight_layout()

# %%
# query that filters the Measurement table to retrieve the precipitation and temperature for the month of December. 
dec_temp_prcp = session.query(Measurement.date, Measurement.tobs, Measurement.prcp).filter(extract('month',Measurement.date) == "12").all()
dec_temp_prcp
# Out:
# [('2010-12-01', 76.0, 0.04),
#  ('2010-12-03', 74.0, 0.0),
#  ('2010-12-04', 74.0, 0.0),
#  ('2010-12-06', 64.0, 0.0),
#  ('2010-12-07', 64.0, 0.0),
#  ('2010-12-08', 67.0, 0.0),
#  ('2010-12-09', 77.0, 0.0),
#  ('2010-12-10', 66.0, 1.58),
#  ('2010-12-11', 69.0, 0.77),
#  ('2010-12-12', 68.0, 0.0),
#  ('2010-12-13', 68.0, 0.0),
#  ('2010-12-14', 71.0, 0.0),
#  ('2010-12-15', 74.0, 0.0),
#  ('2010-12-16', 67.0, 0.0),
#  ('2010-12-17', 66.0, 0.0),
#  ('2010-12-18', 69.0, 0.0),
#  ('2010-12-19', 71.0, 1.4),
#  ('2010-12-23', 70.0, 0.0),
#  ('2010-12-24', 70.0, 0.0),
#  ('2010-12-26', 74.0, None),
#  ('2010-12-27', 74.0, 0.13),
#  ('2010-12-28', 71.0, 0.55),
#  ('2010-12-29', 75.0, 0.06),
#  ('2010-12-30', 75.0, 0.01),
#  ('2010-12-31', 72.0, 0.0),
#  ('2011-12-01', 69.0, 0.03),
#  ('2011-12-02', 68.0, 0.08),
#  ('2011-12-03', 73.0, 0.0),
#  ('2011-12-04', 74.0, 0.0),
#  ('2011-12-05', 73.0, 0.0),
#  ('2011-12-06', 73.0, 0.0),
#  ('2011-12-07', 73.0, 0.0),
#  ('2011-12-08', 73.0, 0.0),
# ...

# %%
dec_temp_prcp_df = pd.DataFrame(dec_temp_prcp, columns=['date','temperature', 'precipitation'])
dec_temp_prcp_df.set_index(dec_temp_prcp_df["date"], inplace=True)
print(dec_temp_prcp_df.to_string(index=False))
# Out:
#       date  temperature  precipitation
# 2010-12-01         76.0           0.04
# 2010-12-03         74.0           0.00
# 2010-12-04         74.0           0.00
# 2010-12-06         64.0           0.00
# 2010-12-07         64.0           0.00
# 2010-12-08         67.0           0.00
# 2010-12-09         77.0           0.00
# 2010-12-10         66.0           1.58
# 2010-12-11         69.0           0.77
# 2010-12-12         68.0           0.00
# 2010-12-13         68.0           0.00
# 2010-12-14         71.0           0.00
# 2010-12-15         74.0           0.00
# 2010-12-16         67.0           0.00
# 2010-12-17         66.0           0.00
# 2010-12-18         69.0           0.00
# 2010-12-19         71.0           1.40
# 2010-12-23         70.0           0.00
# 2010-12-24         70.0           0.00
# 2010-12-26         74.0            NaN
# 2010-12-27         74.0           0.13
# 2010-12-28         71.0           0.55
# 2010-12-29         75.0           0.06
# ...

# %%
dec_temp_prcp_clean_df = dec_temp_prcp_df.dropna()

# %%
dec_temp_prcp_clean_df.describe()
# Out:
#        temperature  precipitation
# count  1405.000000    1405.000000
# mean     70.930249       0.216819
# std       3.741578       0.541399
# min      56.000000       0.000000
# 25%      69.000000       0.000000
# 50%      71.000000       0.030000
# 75%      74.000000       0.150000
# max      81.000000       6.420000

# %%
dec_temp_prcp_clean_df.plot.scatter('temperature', 'precipitation')
plt.title('December Temperature by Precipitation')
plt.xlim([55, 85])
plt.ylim([0,8])
plt.tight_layout()
